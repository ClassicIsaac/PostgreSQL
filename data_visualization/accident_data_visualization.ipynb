# %%
import pandas as pd
import seaborn as sns

# %%
accident_columns=["Accident_Index","Location_Easting_OSGR","Location_Northing_OSGR","Longitude","Latitude","Police_Force","Accident_Severity","Number_of_Vehicles","Number_of_Casualties","Date","Day_of_Week","Time"]

# %%
#Load data from CSV file into a pandas DataFrame
accident=pd.read_csv("C:/Users/ORESANYA/Classic Isaac/Git/PostgreSQL/dataset/Accidents_2015.txt",usecols=accident_columns,dtype={'Accident_Index':str})

# %%
accident_matrix=accident.corr()
accident_matrix
# Out:
#                         Location_Easting_OSGR  Location_Northing_OSGR  \
# Location_Easting_OSGR                1.000000               -0.433536
# Location_Northing_OSGR              -0.433536                1.000000
# Longitude                            0.999376               -0.443053
# Latitude                            -0.435568                0.999973
# Police_Force                        -0.379046                0.178804
# Accident_Severity                    0.051229               -0.037594
# Number_of_Vehicles                   0.015593               -0.028368
# Number_of_Casualties                -0.036257                0.032868
# Day_of_Week                         -0.004499                0.004241
#
#                         Longitude  Latitude  Police_Force  Accident_Severity  \
# Location_Easting_OSGR    0.999376 -0.435568     -0.379046           0.051229
# Location_Northing_OSGR  -0.443053  0.999973      0.178804          -0.037594
# Longitude                1.000000 -0.444983     -0.391877           0.051015
# Latitude                -0.444983  1.000000      0.176864          -0.037748
# Police_Force            -0.391877  0.176864      1.000000          -0.060330
# Accident_Severity        0.051015 -0.037748     -0.060330           1.000000
# Number_of_Vehicles       0.016510 -0.028174     -0.001503           0.070972
# Number_of_Casualties    -0.035038  0.032994      0.013854          -0.065201
# Day_of_Week             -0.004551  0.004232     -0.001045           0.001485
#
#                         Number_of_Vehicles  Number_of_Casualties  Day_of_Week
# Location_Easting_OSGR             0.015593             -0.036257    -0.004499
# Location_Northing_OSGR           -0.028368              0.032868     0.004241
# Longitude                         0.016510             -0.035038    -0.004551
# Latitude                         -0.028174              0.032994     0.004232
# Police_Force                     -0.001503              0.013854    -0.001045
# Accident_Severity                 0.070972             -0.065201     0.001485
# Number_of_Vehicles                1.000000              0.259028     0.001150
# Number_of_Casualties              0.259028              1.000000     0.002011
# Day_of_Week                       0.001150              0.002011     1.000000
